# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("customers-100.csv")
data.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.drop(columns=["Phone 2"],inplace=True)
df.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1  \
# 0                       Chile            229.077.5154
# 1                    Djibouti              5153435776
# 2         Antigua and Barbuda         +1-539-402-0259
# 3          Dominican Republic  001-808-617-6467x12895
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.drop_duplicates()
df.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1  \
# 0                       Chile            229.077.5154
# 1                    Djibouti              5153435776
# 2         Antigua and Barbuda         +1-539-402-0259
# 3          Dominican Republic  001-808-617-6467x12895
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df["Full_Name"] = df["First Name"]+" "+df["Last Name"]
df = df.drop(columns=["First Name","Last Name"])
df
# Out:
#     Index      Customer Id                          Company  \
# 0       1  DD37Cf93aecA6Dc                  Rasmussen Group
# 1       2  1Ef7b82A4CAAD10                      Vega-Gentry
# 2       3  6F94879bDAfE5a6                    Murillo-Perry
# 3       4  5Cef8BFA16c5e3c  Dominguez, Mcmillan and Donovan
# 4       5  053d585Ab6b3159         Martin, Lang and Andrade
# ..    ...              ...                              ...
# 95     96  cb8E23e48d22Eae                        Carey LLC
# 96     97  CeD220bdAaCfaDf            Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db                    Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A               Fitzgerald-Harrell
# 99    100  2354a0E336A91A1               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# 0        East Leonard                       Chile            229.077.5154
# 1   East Jimmychester                    Djibouti              5153435776
# ...

# %%
col = df.pop("Full_Name")
df.insert(2, "Full_Name", col)
df.head(5)
# Out:
#    Index      Customer Id       Full_Name                          Company  \
# 0      1  DD37Cf93aecA6Dc   Sheryl Baxter                  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10  Preston Lozano                      Vega-Gentry
# 2      3  6F94879bDAfE5a6       Roy Berry                    Murillo-Perry
# 3      4  5Cef8BFA16c5e3c     Linda Olsen  Dominguez, Mcmillan and Donovan
# 4      5  053d585Ab6b3159   Joanna Bender         Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# 2      Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 3         Bensonview          Dominican Republic  001-808-617-6467x12895
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df = df.rename(columns={"Full_Name":"Name"})
df.head(5)
# Out:
#    Index      Customer Id            Name                          Company  \
# 0      1  DD37Cf93aecA6Dc   Sheryl Baxter                  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10  Preston Lozano                      Vega-Gentry
# 2      3  6F94879bDAfE5a6       Roy Berry                    Murillo-Perry
# 3      4  5Cef8BFA16c5e3c     Linda Olsen  Dominguez, Mcmillan and Donovan
# 4      5  053d585Ab6b3159   Joanna Bender         Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# 2      Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 3         Bensonview          Dominican Republic  001-808-617-6467x12895
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df.isna().sum()
# Out:
# Index                0
# Customer Id          0
# Name                 0
# Company              0
# City                 0
# Country              0
# Phone 1              0
# Email                0
# Subscription Date    0
# Website              0
# dtype: int64

# %%
df.dropna()
# Out:
#     Index      Customer Id             Name                          Company  \
# 0       1  DD37Cf93aecA6Dc    Sheryl Baxter                  Rasmussen Group
# 1       2  1Ef7b82A4CAAD10   Preston Lozano                      Vega-Gentry
# 2       3  6F94879bDAfE5a6        Roy Berry                    Murillo-Perry
# 3       4  5Cef8BFA16c5e3c      Linda Olsen  Dominguez, Mcmillan and Donovan
# 4       5  053d585Ab6b3159    Joanna Bender         Martin, Lang and Andrade
# ..    ...              ...              ...                              ...
# 95     96  cb8E23e48d22Eae       Karl Greer                        Carey LLC
# 96     97  CeD220bdAaCfaDf    Lynn Atkinson            Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db      Fred Guerra                    Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A    Yvonne Farmer               Fitzgerald-Harrell
# 99    100  2354a0E336A91A1  Clarence Haynes               Le, Nash and Cross
#
# ...

# %%
df['Customer Id'] = df['Customer Id'].astype(str)
df.head(5)
# Out:
#    Index      Customer Id            Name                          Company  \
# 0      1  DD37Cf93aecA6Dc   Sheryl Baxter                  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10  Preston Lozano                      Vega-Gentry
# 2      3  6F94879bDAfE5a6       Roy Berry                    Murillo-Perry
# 3      4  5Cef8BFA16c5e3c     Linda Olsen  Dominguez, Mcmillan and Donovan
# 4      5  053d585Ab6b3159   Joanna Bender         Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# 2      Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 3         Bensonview          Dominican Republic  001-808-617-6467x12895
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df["Customer Id"].unique()
# Out:
# array(['DD37Cf93aecA6Dc', '1Ef7b82A4CAAD10', '6F94879bDAfE5a6',
#        '5Cef8BFA16c5e3c', '053d585Ab6b3159', '2d08FB17EE273F4',
#        'EA4d384DfDbBf77', '0e04AFde9f225dE', 'C2dE4dEEc489ae0',
#        '8C2811a503C7c5a', '216E205d6eBb815', 'CEDec94deE6d69B',
#        'e35426EbDEceaFF', 'A08A8aF8BE9FaD4', '6fEaA1b7cab7B6C',
#        '8cad0b4CBceaeec', 'a5DC21AE3a21eaA', 'F8Aa9d6DfcBeeF8',
#        'F160f5Db3EfE973', '0F60FF3DdCd7aB0', '9F9AdB7B8A6f7F2',
#        'FBd0Ded4F02a742', '2FB0FAA1d429421', '010468dAA11382c',
#        'eC1927Ca84E033e', '09D7D7C8Fe09aea', 'aBdfcF2c50b0bfD',
#        'b92EBfdF8a3f0E6', '3B5dAAFA41AFa22', 'EDA69ca7a6e96a2',
#        '64DCcDFaB9DFd4e', '679c6c83DD872d6', '7Ce381e4Afa4ba9',
#        'A09AEc6E3bF70eE', 'aA9BAFfBc3710fe', 'E11dfb2DB8C9f72',
#        '889eCf90f68c5Da', '7a1Ee69F4fF4B4D', 'dca4f1D0A0fc5c9',
#        '17aD8e2dB3df03D', '2f79Cd309624Abb', '6e5ad5a5e2bB5Ca',
#        '7E441b6B228DBcA', 'D3fC11A9C235Dc6', '30Dfa48fe5Ede78',
# ...

# %%
df["Country"] = df["Country"].replace({"Fiji" : "Fuji"})
df.head(-12)
# Out:
#     Index      Customer Id             Name                          Company  \
# 0       1  DD37Cf93aecA6Dc    Sheryl Baxter                  Rasmussen Group
# 1       2  1Ef7b82A4CAAD10   Preston Lozano                      Vega-Gentry
# 2       3  6F94879bDAfE5a6        Roy Berry                    Murillo-Perry
# 3       4  5Cef8BFA16c5e3c      Linda Olsen  Dominguez, Mcmillan and Donovan
# 4       5  053d585Ab6b3159    Joanna Bender         Martin, Lang and Andrade
# ..    ...              ...              ...                              ...
# 83     84  78C06E9b6B3DF20    Chad Davidson                   Garcia-Jimenez
# 84     85  03A1E62ADdeb31c       Corey Holt       Mcdonald, Bird and Ramirez
# 85     86  C6763c99d0bd16D  Emma Cunningham                     Stephens Inc
# 86     87  ebe77E5Bf9476CE      Duane Woods                   Montoya-Miller
# 87     88  E4Bbcd8AD81fC5f    Alison Vargas          Vaughn, Watts and Leach
#
# ...

# %%
df["Name"] = df["Name"].str.lower()
df.head(5)
# Out:
#    Index      Customer Id            Name                          Company  \
# 0      1  DD37Cf93aecA6Dc   sheryl baxter                  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10  preston lozano                      Vega-Gentry
# 2      3  6F94879bDAfE5a6       roy berry                    Murillo-Perry
# 3      4  5Cef8BFA16c5e3c     linda olsen  Dominguez, Mcmillan and Donovan
# 4      5  053d585Ab6b3159   joanna bender         Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# 2      Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 3         Bensonview          Dominican Republic  001-808-617-6467x12895
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
# ...

# %%
df = df.reindex(sorted(df.columns), axis=1)
df.head(5)
# Out:
#                 City                          Company  \
# 0       East Leonard                  Rasmussen Group
# 1  East Jimmychester                      Vega-Gentry
# 2      Isabelborough                    Murillo-Perry
# 3         Bensonview  Dominguez, Mcmillan and Donovan
# 4     West Priscilla         Martin, Lang and Andrade
#
#                       Country      Customer Id                        Email  \
# 0                       Chile  DD37Cf93aecA6Dc     zunigavanessa@smith.info
# 1                    Djibouti  1Ef7b82A4CAAD10              vmata@colon.com
# 2         Antigua and Barbuda  6F94879bDAfE5a6          beckycarr@hogan.com
# 3          Dominican Republic  5Cef8BFA16c5e3c  stanleyblackwell@benson.org
# 4  Slovakia (Slovak Republic)  053d585Ab6b3159      colinalvarado@miles.net
#
#    Index            Name                 Phone 1 Subscription Date  \
# 0      1   sheryl baxter            229.077.5154        2020-08-24
# ...

# %%
cl = df.pop("Index")
df.insert(0,"Index",cl)
df.head(3)
# Out:
#    Index               City          Company              Country  \
# 0      1       East Leonard  Rasmussen Group                Chile
# 1      2  East Jimmychester      Vega-Gentry             Djibouti
# 2      3      Isabelborough    Murillo-Perry  Antigua and Barbuda
#
#        Customer Id                     Email            Name          Phone 1  \
# 0  DD37Cf93aecA6Dc  zunigavanessa@smith.info   sheryl baxter     229.077.5154
# 1  1Ef7b82A4CAAD10           vmata@colon.com  preston lozano       5153435776
# 2  6F94879bDAfE5a6       beckycarr@hogan.com       roy berry  +1-539-402-0259
#
#   Subscription Date                     Website
# 0        2020-08-24  http://www.stephenson.com/
# 1        2021-04-23       http://www.hobbs.com/
# 2        2020-03-25    http://www.lawrence.com/

# %%
df
# Out:
#     Index               City                          Company  \
# 0       1       East Leonard                  Rasmussen Group
# 1       2  East Jimmychester                      Vega-Gentry
# 2       3      Isabelborough                    Murillo-Perry
# 3       4         Bensonview  Dominguez, Mcmillan and Donovan
# 4       5     West Priscilla         Martin, Lang and Andrade
# ..    ...                ...                              ...
# 95     96       East Richard                        Carey LLC
# 96     97       New Bradview            Ware, Burns and Oneal
# 97     98         Ortegaland                    Schmitt-Jones
# 98     99    Lake Elijahview               Fitzgerald-Harrell
# 99    100          Judymouth               Le, Nash and Cross
#
#                        Country      Customer Id  \
# 0                        Chile  DD37Cf93aecA6Dc
# 1                     Djibouti  1Ef7b82A4CAAD10
# 2          Antigua and Barbuda  6F94879bDAfE5a6
# ...

# %%
df.to_csv("cleaned_data.csv", index=False)
